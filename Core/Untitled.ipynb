# %%
import requests
from bs4 import BeautifulSoup as bs

# %% [raw]
# url  ="https://www.google.com/search?q=computer+programming&biw=1707&bih=848&tbm=nws&sxsrf=ALeKk00AQJDYbJSAc7XQdz0LLQSga2gCqA%3A1616298358532&ei=dsFWYJWBIPqZ4-EPwcWl0Ac&oq=computer+programming&gs_l=psy-ab.3..33i10k1.20046.23174.0.23298.20.18.0.0.0.0.316.2894.0j5j6j2.13.0....0...1c.1.64.psy-ab..7.9.1929...0.0.kt0BWaLusP0"

# %%
url = "https://www.google.com/search?q=computer+programming&tbm=nws"

# %%
instance = requests.get(url)

# %%
soup = bs(instance.content,'html.parser')

# %%
data = soup.find_all('g-card',class_="nChh6e ")

# %%
data
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import time

        

class Hiring:
    def __init__(self):
        pass
    
    def instance(self):
        url = "https://www.indeed.co.in/companies?from=gnav-homepage"
        data = requests.get(url)
        content = data.content
        soup = bs(content,'html.parser')
        return soup
    def get_data(self,instance):
        df ={}
        soup = instance.find('div',class_="cmp-PopularCompaniesWidget-companyName")
        img = instance.find('img')
        link = instance.find('a')
        if soup and img:
            df['name'] = soup.text.strip()
            df['logo'] = img['src']
            df['link'] = "https://in.indeed.com"+link['href']+'/jobs'
            
        return df
            
    def getinfo(self):
        soup = self.instance()
        soup = soup.find_all('div',class_="icl-Grid-col")
        
        df = []
        for ins in soup:
            name = self.get_data(ins)
            if name:
                df.append(name)
            
            
        return df
        
    
    def extract(self):
        data = self.getinfo()
        return data


class Indeed:
    def __init__(self,keyword,location,frompage,start):
        self.jobs = keyword
        self.location = location
        self.frompage = 'last'
        self.start = start
    def load_indeed(self):
        if self.start == 0:
            url = f"https://www.indeed.co.in/jobs?q={self.jobs}&l={self.location}&fromage={self.frompage}"
        else:
            url = f"https://www.indeed.co.in/jobs?q={self.jobs}&l={self.location}&fromage={self.frompage}&start={self.start}"
            
        data = requests.get(url)
        data = data.content
        soup = bs(data,"html.parser")
        job_soup = soup.find(id="resultsCol")
        return job_soup
    def indeed_title(self,element):
        try:
            title_elem = element.find('h2', class_='title')
            title = title_elem.text.strip()
        except:
            title = ""
        return title
    def indeed_summary(self,element):
        try:
            summary = element.find('div',class_ = 'summary')
            summary = summary.text
        except:
            summary = ""
        return summary
    def extract_company_indeed(self,job_elem,loca):
        db = {}
        try:
            company_elem = job_elem.find('div', class_='sjcl')
            company_data = company_elem.find('span',class_ = 'company')
            company = company_data.text.strip()
        except:
            company = ""
            
        try:
            location_data = company_elem.find('span',class_ = 'location')
            location = location_data.text.strip()
        except:
            location=loca.capitalize()
        #remote_data = company_elem.find('span',class_ = 'remote')
        #remote = remote_data.text.strip()
        #req_data = company_elem.find('div',class_='summary')
        #req = req_data.text.strip()
        
        
        db['company'] = company
        db['location'] = location
        #db['requirement'] = req_data
        #db['method'] = remote
        return db

    def extract_link_indeed(self,job_elem):
        link = job_elem.find('a')['href']
        link = 'https://www.indeed.co.in' + link
        return link
    def extract_requirement(self,element):
        #req_elem = element.find('div', class_='jobCardReqContainer')
        try:
            data = element.find('div',class_ = 'jobCardReqList')
            sol = ""
            for i in data.find_all('div',class_='jobCardReqItem'):
                sol += i.text.strip() + '\n'
            
        except:
            sol = ""
        #req = req_elem.text.strip()
        return sol
    def extract_date_indeed(self,job_elem):
        try:
            date_elem = job_elem.find('span', class_='date')
            date = date_elem.text.strip()
        except:
            date=""
        return date
    
    
    def extract_salary(self,element):
        try:
            salary = element.find('span',class_="salaryText")
            salary = salary.text.strip()
        except:
            salary = ""
        return salary
    def get_indeed_job_data(self):
        db = list()
        instance = self.load_indeed()
        data = instance.find_all('div', class_='jobsearch-SerpJobCard')
        for x in data:
            try:
                sol = dict()
                title = self.indeed_title(x)
                company = self.extract_company_indeed(x,self.location)
                link = self.extract_link_indeed(x)
                date = self.extract_date_indeed(x)
                summary = self.indeed_summary(x)
                req = self.extract_requirement(x)
                salary = self.extract_salary(x)
                sol['title'] = title
                sol['company'] = company
                sol['link'] = link
                sol['date'] = date
                sol['summary'] = summary
                sol['requirement'] = req
                sol['salary'] = salary
                sol['jobs'] = 'Full Time'
                db.append(sol)
            except:
                pass
        return db
    def extract(self):
        soup = self.get_indeed_job_data()
        return soup
        

class Monster:
    def __init__(self,designation,location,start=0,limit=25,sort=1):
        self.desig = designation
        self.location = location
        self.limit = limit
        self.sort = sort
        self.start = start
    def get_link(self):
        link = f'https://www.monsterindia.com/srp/results?start={self.start}&sort={self.sort}&limit={self.limit}&query={self.desig}&locations={self.location}'
        return link
    def get_instance(self):
        options = webdriver.ChromeOptions()
        options.add_argument("headless")
        driver = webdriver.Chrome("C:\chromedriver_win32\chromedriver.exe",options=options)
        driver.get(self.get_link())
        soup = bs(driver.page_source,'html5lib')
        driver.close()
        return soup
    def extract(self):
        data = []
        soup = self.get_instance()
        element = soup.find_all('div', class_="card-panel apply-panel job-apply-card")
        for job in element:
            try:
                d = {}
                d['title'] = job.find('div',class_="job-tittle").find('a').text
                d['link'] = job.find('div',class_="job-tittle").find('a').get('href')
                d['company'] = {'company':job.find('span',class_="company-name").text,'location':self.location}
                data1 = job.find('div',class_="searctag row").find_all('span',class_="loc")
                if len(data1)>2:
                    d['experience'] = data1[1].text
                    d['salary'] = data1[2].text
                else:
                    d['experience'] = data1[1].text
                    d['salary'] = 'Not Disclosed'
                d['summary'] = job.find('p',class_="job-descrip").text
                try:
                    tags = job.find('p',class_="descrip-skills").find_all('span',class_="grey-link")
                    l = []
                    for i in tags:
                        l.append(i.text.strip().rstrip(","))
                except:
                    l=[]
                    
                    
                d['tags'] = l
                d['date']=job.find('span',class_="posted").text
                d['jobs']='Full Time'
                data.append(d)
            except:
                pass
        return data     
class Naukri:
    def __init__(self,designation,location,page):
        self.desig = designation
        self.city = location
        self.page = page
        
    def get_link(self):
        if self.desig and self.city is None:
            link = f'https://www.naukri.com/{self.desig}-jobs-{self.page}'
        elif self.city and self.desig is None:
            link = f"https://www.naukri.com/jobs-in-{self.city}-{self.page}"
        else:
            link = f'https://www.naukri.com/{self.desig}-jobs-in-{self.city}-{self.page}'
        return link
    
    def get_instance(self):
        options = webdriver.ChromeOptions()
        options.add_argument("headless")
        driver = webdriver.Chrome("C:\chromedriver_win32\chromedriver.exe",options=options)
        driver.get(self.get_link())
        soup = bs(driver.page_source,'html5lib')
        driver.close()
        return soup
    
    def extract(self):
        soup = self.get_instance()
        results = soup.find(class_='list')
        job_elems = results.find_all('article',class_='jobTuple bgWhite br4 mb-8')
        data=[]
        for job in job_elems:
            try:
                d = {
                    'link':job.find('a',class_="title fw500 ellipsis").get('href'),
                    'title':job.find('a',class_="title fw500 ellipsis").text,
                    'company':{'company':job.find('a',class_="subTitle").text,'location':self.city},
                    'experience':job.find('li',class_="experience").text,
                    'salary':job.find('li',class_="salary").text,
                    'summary':job.find('div',class_="job-description").text,
                    'date':job.find('div',class_="jobTupleFooter").find_all('span')[1].text,
                    'jobs':'Full Time'
                }
                tags = job.find('ul',class_="tags has-description")
                l = []
                for i in tags.find_all('li'):
                    l.append(i.text)
                d['tags'] = l
                rating = job.find('span',class_="starRating fleft dot")
                if rating is None:
                    rate = ""
                else:
                    rate = rating.text
                d['rating'] = rate
                review = job.find('a',class_="reviewsCount")
                if review is None:
                    Rev = ""
                else:
                    Rev = review.text
                d['review'] = Rev
                data.append(d)
            except:
                pass
        return data
        
        
        
class Jobs(Indeed,Monster,Naukri):
    '''
    Jobs(keyword,location,page)
    '''
    def __init__(self,keyword,location,page):
        self.keyword = keyword
        self.location = location
        self.page = page
    def indeed(self,start):
        i1 = Indeed(self.keyword,self.location,'last',start)
        i2 = Indeed(self.keyword,self.location,'last',start+10)
        return i1.extract() + i2.extract()
    def monster(self,start):
        i1 = Monster(self.keyword,self.location,start)
        return i1.extract()
    def naukri(self,page):
        i1 = Naukri(self.keyword,self.location,page)
        return i1.extract()
        
        
    def select(self):
        if self.page == 1:
            return self.indeed(0)
        elif self.page == 2:
            return self.indeed(20)
        elif self.page == 3:
            return self.monster(0)
        elif self.page == 4:
            return self.monster(25)
        elif self.page == 5:
            return self.indeed(40)
        elif self.page==6:
            return self.naukri(1)
        elif self.page == 7:
            return self.naukri(2)
        elif self.page == 8:
            return self.indeed(60)
        elif self.page == 9:
            return self.monster(50)
        elif self.page == 10:
            return self.naukri(3)

# %%
url = "https://www.google.com/search?q=computer+programming&tbm=nws"

# %%
instance = requests.get(url)

# %%
options = webdriver.ChromeOptions()
options.add_argument("headless")
driver = webdriver.Chrome("C:\chromedriver_win32\chromedriver.exe",options=options)
driver.get(URL)
soup = bs(driver.page_source,'html5lib')
driver.close()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-19-bfed9fdb1173> in <module>
#       1 options = webdriver.ChromeOptions()
#       2 options.add_argument("headless")
# ----> 3 driver = webdriver.Chrome("C:\chromedriver_win32\chromedriver.exe",options=options)
#       4 driver.get(URL)
#       5 soup = bs(driver.page_source,'html5lib')
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     155             warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                           DeprecationWarning, stacklevel=2)
# --> 157         self.start_session(capabilities, browser_profile)
#     158         self._switch_to = SwitchTo(self)
#     159         self._mobile = Mobile(self)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in start_session(self, capabilities, browser_profile)
#     250         parameters = {"capabilities": w3c_caps,
#     251                       "desiredCapabilities": capabilities}
# --> 252         response = self.execute(Command.NEW_SESSION, parameters)
#     253         if 'sessionId' not in response:
#     254             response = response['value']
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 87
# Current browser version is 89.0.4389.90 with binary path C:\Program Files (x86)\Google\Chrome\Application\chrome.exe

# %%
from bs4 import BeautifulSoup
import requests

url="https://news.google.co.in/"
code=requests.get(url)
soup=BeautifulSoup(code.text,'html5lib')
for title in soup.find_all('span',class_="titletext"):
    print(title.text)

# %%
import bs4
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen

news_url="https://news.google.com/news?q=coding"
Client=requests.get(url)

soup_page=soup(Client.content,"html.parser")
news_list=soup_page.findAll("article")
for i in news_list:
    print(i.find_all('h3',class_="ipQwMb"))
# Print news title, url and publish date
# Out:
# [<h3 class="ipQwMb ekueJc RD0gLb"><a class="DY5T1d RZIKme" href="....?hl=en-IN&amp;gl=IN&amp;ceid=IN%3Aen">Home Minister asked cops to collect Rs 100 crore for him per month: Parambir Singh drops letter bomb</a></h3>]
# []
# []
# []
# []
# [<h3 class="ipQwMb ekueJc RD0gLb"><a class="DY5T1d RZIKme" href="./articles/CAIiEFotIfAq5z4-_H56z85ym-cqGAgEKg8IACoHCAow3rvTBDD89X4w8YzmBQ?hl=en-IN&amp;gl=IN&amp;ceid=IN%3Aen">In BJP Bengal list, 36 joined the party over last six months</a></h3>]
# []
# []
# []
# []
# [<h3 class="ipQwMb ekueJc RD0gLb"><a class="DY5T1d RZIKme" href="./articles/CAIiEA5MoUFZbaR9gGsxEgo85MMqGQgEKhAIACoHCAowlbCPCzCrzaIDMLL1zQY?hl=en-IN&amp;gl=IN&amp;ceid=IN%3Aen">COVID-19 | Senior citizens, pregnant women exempted from mandatory institutional quarantine: BMC</a></h3>]
# []
# []
# []
# []
# [<h3 class="ipQwMb ekueJc RD0gLb"><a class="DY5T1d RZIKme" href="./articles/CAIiEExvgKBazLDD535IdYNaE1QqGQgEKhAIACoHCAowj8n_CjDIrfkCMJWZ2AY?hl=en-IN&amp;gl=IN&amp;ceid=IN%3Aen">BJP Wants Action Against Mamata Banerjee For Amit Shah "Smear Campaign"</a></h3>]
# [<h3 class="ipQwMb ekueJc RD0gLb"><a class="DY5T1d RZIKme" href="./articles/CAIiEBOx1TQT2NwOCeIy_dP-QQgqGQgEKhAIACoHCAowzrL9CjDC7vQCMJmD1wU?hl=en-IN&amp;gl=IN&amp;ceid=IN%3Aen">Ashoka students give 2-day strike call to press for Pratap Bhanu’s reinstatement</a></h3>]
# []
# []
# []
# []
# [<h3 class="ipQwMb ekueJc RD0gLb"><a class="DY5T1d RZIKme" href="./articles/CAIiEMlcPuam14fxx7asseVVm08qFwgEKg4IACoGCAoww7k_MMevCDCDuK0G?hl=en-IN&amp;gl=IN&amp;ceid=IN%3Aen">‘Bring CIA and KGB too’: Shiv Sena on transfer of Mansukh Hiran death probe to NIA</a></h3>]
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
news_list

# %%
soup_page

# %%
import feedparser
from bs4 import BeautifulSoup

class ParseFeed():

    def __init__(self,topic):
        self.feed_url = f"http://news.google.com/news?q={topic}&hl=en-US&sort=date&gl=US&num=100&output=rss"
        self.topic = topic
        
    def clean(self, html):
        '''
        Get the text from html and do some cleaning
        '''
        soup = BeautifulSoup(html)
        text = soup.get_text()
        text = text.replace('\xa0', ' ')
        return text

    def parse(self):
        '''
        Parse the URL, and print all the details of the news 
        '''
        feeds = feedparser.parse(self.feed_url).entries
        data = []
        for f in feeds:
            print(f)
            data.append({
                'Description': self.clean(f.get("description", "")),
                'Published Date': f.get("published", ""),
                'Title': f.get("title", ""),
                'Url': f.get("link", ""),
              
            })
        return data
            
feed = ParseFeed('Computer-Programming')
data = feed.parse()
# Out:
# {'title': "Get 'Computer Programming for Absolute Beginners' ($24.99 value) for FREE - BetaNews", 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': "Get 'Computer Programming for Absolute Beginners' ($24.99 value) for FREE - BetaNews"}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://betanews.com/2021/03/18/computer-programming-for-absolute-beginners-free/'}], 'link': 'https://betanews.com/2021/03/18/computer-programming-for-absolute-beginners-free/', 'id': 'CBMiUWh0dHBzOi8vYmV0YW5ld3MuY29tLzIwMjEvMDMvMTgvY29tcHV0ZXItcHJvZ3JhbW1pbmctZm9yLWFic29sdXRlLWJlZ2lubmVycy1mcmVlL9IBAA', 'guidislink': False, 'published': 'Thu, 18 Mar 2021 14:09:16 GMT', 'published_parsed': time.struct_time(tm_year=2021, tm_mon=3, tm_mday=18, tm_hour=14, tm_min=9, tm_sec=16, tm_wday=3, tm_yday=77, tm_isdst=0), 'summary': '<a href="https://betanews.com/2021/03/18/computer-programming-for-absolute-beginners-free/" target="_blank">Get \'Computer Programming for Absolute Beginners\' ($24.99 value) for FREE</a>&nbsp;&nbsp;<font color="#6f6f6f">BetaNews</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https://betanews.com/2021/03/18/computer-programming-for-absolute-beginners-free/" target="_blank">Get \'Computer Programming for Absolute Beginners\' ($24.99 value) for FREE</a>&nbsp;&nbsp;<font color="#6f6f6f">BetaNews</font>'}, 'source': {'href': 'https://betanews.com', 'title': 'BetaNews'}}
# {'title': "One young artist's search to balance art and computer programming - The Warwick Advertiser", 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': "One young artist's search to balance art and computer programming - The Warwick Advertiser"}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://www.warwickadvertiser.com/news/local-news/one-young-artist-s-search-to-balance-art-and-computer-programming-XF1557330'}], 'link': 'http://www.warwickadvertiser.com/news/local-news/one-young-artist-s-search-to-balance-art-and-computer-programming-XF1557330', 'id': 'CBMifGh0dHA6Ly93d3cud2Fyd2lja2FkdmVydGlzZXIuY29tL25ld3MvbG9jYWwtbmV3cy9vbmUteW91bmctYXJ0aXN0LXMtc2VhcmNoLXRvLWJhbGFuY2UtYXJ0LWFuZC1jb21wdXRlci1wcm9ncmFtbWluZy1YRjE1NTczMzDSAQA', 'guidislink': False, 'published': 'Fri, 12 Mar 2021 19:07:30 GMT', 'published_parsed': time.struct_time(tm_year=2021, tm_mon=3, tm_mday=12, tm_hour=19, tm_min=7, tm_sec=30, tm_wday=4, tm_yday=71, tm_isdst=0), 'summary': '<a href="http://www.warwickadvertiser.com/news/local-news/one-young-artist-s-search-to-balance-art-and-computer-programming-XF1557330" target="_blank">One young artist\'s search to balance art and computer programming</a>&nbsp;&nbsp;<font color="#6f6f6f">The Warwick Advertiser</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href
 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': 'These 15 Coding Books Might Spark the Inner Programmer in Your Kid - POPSUGAR'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.popsugar.com/family/books-about-coding-for-kids-48216978'}], 'link': 'https://www.popsugar.com/family/books-about-coding-for-kids-48216978', 'id': 'CAIiEBU00Tb04bpO2f6-hgrNcGwqEwgEKgwIACoFCAowgGgwwAUwwQ8', 'guidislink': False, 'published': 'Fri, 19 Mar 2021 21:10:03 GMT', 'published_parsed': time.struct_time(tm_year=2021, tm_mon=3, tm_mday=19, tm_hour=21, tm_min=10, tm_sec=3, tm_wday=4, tm_yday=78, tm_isdst=0), 'summary': '<a href="https://www.popsugar.com/family/books-about-coding-for-kids-48216978" target="_blank">These 15 Coding Books Might Spark the Inner Programmer in Your Kid</a>&nbsp;&nbsp;<font color="#6f6f6f">POPSUGAR</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https://www.popsugar.com/family/books-about-coding-for-kids-48216978" target="_blank">These 15 Coding Books Might Spark the Inner Programmer in Your Kid</a>&nbsp;&nbsp;<font color="#6f6f6f">POPSUGAR</font>'}, 'source': {'href': 'https://www.popsugar.com', 'title': 'POPSUGAR'}}
# {'title': 'Syracuse University to offer online, part-time computer programming degree - The Daily Orange', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': 'Syracuse University to offer online, part-time computer programming degree - The Daily Orange'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://dailyorange.com/2021/02/syracuse-university-offer-online-part-time-computer-programming-degree/'}], 'link': 'http://dailyorange.com/2021/02/syracuse-university-offer-online-part-time-computer-programming-degree/', 'id': 'CBMiZmh0dHA6Ly9kYWlseW9yYW5nZS5jb20vMjAyMS8wMi9zeXJhY3VzZS11bml2ZXJzaXR5LW9mZmVyLW9ubGluZS1wYXJ0LXRpbWUtY29tcHV0ZXItcHJvZ3JhbW1pbmctZGVncmVlL9IBAA', 'guidislink': False, 'published': 'Wed, 24 Feb 2021 08:00:00 GMT', 'published_parsed': time.struct_time(tm_year=2021, tm_mon=2, tm_mday=24, tm_hour=8, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=55, tm_isdst=0), 'summary': '<a href="http://dailyorange.com/2021/02/syracuse-university-offer-online-part-time-computer-programming-degree/" target="_blank">Syracuse University to offer online, part-time computer programming degree</a>&nbsp;&nbsp;<font color="#6f6f6f">The Daily Orange</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="http://dailyorange.com/2021/02/syracuse-university-offer-online-part-time-computer-programming-degree/" target="_blank">Syracuse University to offer online, part-time computer programming degree</a>&nbsp;&nbsp;<font color="#6f6f6f">The Daily Orange</font>'}, 'source': {'href': 'http://dailyorange.com', 'title': 'The Daily Orange'}}
# {'title': 'Launch a career in computer programming with a boost from this low-cost course bundle - Newsday', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': 'Launch a career in computer programming with a boost from this low-cost course bundle - Newsday'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.newsday.com/lifestyle/fashion-and-shopping/deals/premium-python-certification-bootcamp-bundle-1.50181018'}], 'link': 'https://www.newsday.com/lifestyle/fashion-and-shopping/deals/premium-python-certification-bootcamp-bundle-1.50181018', 'id': '', 'guidislink': False, 'published': 'Tue, 16 Mar 2021 12:00:48 GMT', 'published_parsed': time.struct_time(tm_year=2021, tm_mon=3, tm_mday=16, tm_hour=12, tm_min=0, tm_sec=48, tm_wday=1, tm_yday=75, tm_isdst=0), 'summary': '<a href="https://www.newsday.com/lifestyle/fashion-and-shopping/deals/premium-python-certification-bootcamp-bundle-1.50181018" target="_blank">Launch a career in computer programming with a boost from this low-cost course bundle</a>&nbsp;&nbsp;<font color="#6f6f6f">Newsday</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https://www.newsday.com/lifestyle/fashion-and-shopping/deals/premium-python-certification-bootcamp-bundle-1.50181018" target="_blank">Launch a career in computer programming with a boost from this low-cost course bundle</a>&nbsp;&nbsp;<font color="#6f6f6f">Newsday</font>'}, 'source': {'href': 'https://www.newsday.com', 'title': 'Newsday'}}
# {'title': 'How does the brain interpret computer languages? - Ars Technica', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': 'How does the brain interpret computer languages? - Ars Technica'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://arstechnica.com/science/2021/03/how-does-the-brain-interpret-computer-languages/'}], 'link': 'https://arstechnica.com/science/2021/03/how-does-the-brain-interpret-computer-languages/', 'id': 'CBMiWGh0dHBzOi8vYXJzdGVjaG5pY2EuY29tL3NjaWVuY2UvMjAyMS8wMy9ob3ctZG9lcy10aGUtYnJhaW4taW50ZXJwcmV0LWNvbXB1dGVyLWxhbmd1YWdlcy_SAV5odHRwczovL2Fyc3RlY2huaWNhLmNvbS9zY2llbmNlLzIwMjEvMDMvaG93LWRvZXMtdGhlLWJyYWluLWludGVycHJldC1jb21wdXRlci1sYW5ndWFnZXMvP2FtcD0x', 'guidislink': False, 'published': 'Mon, 15 Mar 2021 17:58:01 GMT', 'published_parsed': time.struct_time(tm_year=2021, tm_mon=3, tm_mday=15, tm_hour=17, tm_min=58, tm_sec=1, tm_wday=0, tm_yday=74, tm_isdst=0), 'summary': '<a href="https://arstechnica.com/science/2021/03/how-does-the-brain-interpret-computer-languages/" target="_blank">How does the brain interpret computer languages?</a>&nbsp;&nbsp;<font color="#6f6f6f">Ars Technica</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https://arstechnica.com/science/2021/03/how-does-the-brain-interpret-computer-languages/" target="_blank">How does the brain interpret computer languages?</a>&nbsp;&nbsp;<font color="#6f6f6f">Ars Technica</font>'}, 'source': {'href': 'https://arstechnica.com', 'title': 'Ars Technica'}}
# {'title': 'Coding for Qubits: How to Program in Quantum Computer Assembly Language - IEEE Spectrum', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': 'Coding for Qubits: How to Program in Quantum Computer Assembly Language - IEEE Spectrum'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://spectrum.ieee.org/tech-talk/computing/software/qscout-sandia-open-source-quantum-computer-and-jaqal-quantum-assembly-language'}], 'link': 'https://spectrum.ieee.org/tech-talk/computing/software/qscout-sandia-open-source-quantum-computer-and-jaqal-quantum-assembly-language', 'id': 'CBMihQFodHRwczovL3NwZWN0cnVtLmllZWUub3JnL3RlY2gtdGFsay9jb21wdXRpbmcvc29mdHdhcmUvcXNjb3V0LXNhbmRpYS1vcGVuLXNvdXJjZS1xdWFudHVtLWNvbXB1dGVyLWFuZC1qYXFhbC1xdWFudHVtLWFzc2VtYmx5LWxhbmd1YWdl0gEA', 'guidislink': False, 'published': 'Fri, 19 Feb 2021 08:00:00 GMT', 'published_parsed': time.struct_time(tm_year=2021, tm_mon=2, tm_mday=19, tm_hour=8, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=50, tm_isdst=0), 'summary': '<a href="https://spectrum.ieee.org/tech-talk/computing/software/qscout-sandia-open-source-quantum-computer-and-jaqal-quantum-assembly-language" target="_blank">Coding for Qubits: How to Program in Quantum Computer Assembly Language</a>&nbsp;&nbsp;<font color="#6f6f6f">IEEE Spectrum</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https
GMT', 'published_parsed': time.struct_time(tm_year=2021, tm_mon=3, tm_mday=18, tm_hour=0, tm_min=1, tm_sec=42, tm_wday=3, tm_yday=77, tm_isdst=0), 'summary': '<a href="https://www.timescall.com/2021/03/17/sunset-middle-gets-computer-science-boost-through-amazon-stem-program" target="_blank">Sunset Middle gets computer science boost through Amazon STEM program</a>&nbsp;&nbsp;<font color="#6f6f6f">Longmont Times-Call</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https://www.timescall.com/2021/03/17/sunset-middle-gets-computer-science-boost-through-amazon-stem-program" target="_blank">Sunset Middle gets computer science boost through Amazon STEM program</a>&nbsp;&nbsp;<font color="#6f6f6f">Longmont Times-Call</font>'}, 'source': {'href': 'https://www.timescall.com', 'title': 'Longmont Times-Call'}}
# {'title': 'New Arkansas bill proposed to classify computer science as foreign language - KARK', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': 'New Arkansas bill proposed to classify computer science as foreign language - KARK'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.kark.com/news/local-news/new-arkansas-bill-proposed-to-classify-computer-science-as-foreign-language/'}], 'link': 'https://www.kark.com/news/local-news/new-arkansas-bill-proposed-to-classify-computer-science-as-foreign-language/', 'id': '', 'guidislink': False, 'published': 'Mon, 15 Mar 2021 23:37:53 GMT', 'published_parsed': time.struct_time(tm_year=2021, tm_mon=3, tm_mday=15, tm_hour=23, tm_min=37, tm_sec=53, tm_wday=0, tm_yday=74, tm_isdst=0), 'summary': '<a href="https://www.kark.com/news/local-news/new-arkansas-bill-proposed-to-classify-computer-science-as-foreign-language/" target="_blank">New Arkansas bill proposed to classify computer science as foreign language</a>&nbsp;&nbsp;<font color="#6f6f6f">KARK</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https://www.kark.com/news/local-news/new-arkansas-bill-proposed-to-classify-computer-science-as-foreign-language/" target="_blank">New Arkansas bill proposed to classify computer science as foreign language</a>&nbsp;&nbsp;<font color="#6f6f6f">KARK</font>'}, 'source': {'href': 'https://www.kark.com', 'title': 'KARK'}}
# {'title': 'Coding and software development are top skills chosen to aid employment opportunities - Intelligent CIO ME', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': 'Coding and software development are top skills chosen to aid employment opportunities - Intelligent CIO ME'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.intelligentcio.com/eu/2021/03/17/coding-and-software-development-are-top-skills-chosen-to-aid-employment-opportunities/'}], 'link': 'https://www.intelligentcio.com/eu/2021/03/17/coding-and-software-development-are-top-skills-chosen-to-aid-employment-opportunities/', 'id': 'CBMigwFodHRwczovL3d3dy5pbnRlbGxpZ2VudGNpby5jb20vZXUvMjAyMS8wMy8xNy9jb2RpbmctYW5kLXNvZnR3YXJlLWRldmVsb3BtZW50LWFyZS10b3Atc2tpbGxzLWNob3Nlbi10by1haWQtZW1wbG95bWVudC1vcHBvcnR1bml0aWVzL9IBAA', 'guidislink': False, 'published': 'Wed, 17 Mar 2021 12:19:09 GMT', 'published_parsed': time.struct_time(tm_year=2021, tm_mon=3, tm_mday=17, tm_hour=12, tm_min=19, tm_sec=9, tm_wday=2, tm_yday=76, tm_isdst=0), 'summary': '<a href="https://www.intelligentcio.com/eu/2021/03/17/coding-and-software-development-are-top-skills-chosen-to-aid-employment-opportunities/" target="_blank">Coding and software development are top skills chosen to aid employment opportunities</a>&nbsp;&nbsp;<font color="#6f6f6f">Intelligent CIO ME</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https://www.intelligentcio.com/eu/2021/03/17/coding-and-software-development-are-top-skills-chosen-to-aid-employment-opportunities/" target="_blank">Coding and software development are top skills chosen to aid employment opportunities</a>&nbsp;&nbsp;<font color="#6f6f6f">Intelligent CIO ME</font>'}, 'source': {'href': 'https://www.intelligentcio.com', 'title': 'Intelligent CIO ME'}}
# {'title': "Thomas Joseph 'Tom,' 'Tommy' Gaven Jr., 62, retired computer programmer with the IRS - Port City Daily", 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value
 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': 'Alan Denton Averill, worked in computer programming for many years - WYDaily'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://wydaily.com/obits/2020/12/01/alan-denton-averill-worked-in-computer-programming-for-many-years/'}], 'link': 'https://wydaily.com/obits/2020/12/01/alan-denton-averill-worked-in-computer-programming-for-many-years/', 'id': 'CBMiZ2h0dHBzOi8vd3lkYWlseS5jb20vb2JpdHMvMjAyMC8xMi8wMS9hbGFuLWRlbnRvbi1hdmVyaWxsLXdvcmtlZC1pbi1jb21wdXRlci1wcm9ncmFtbWluZy1mb3ItbWFueS15ZWFycy_SAQA', 'guidislink': False, 'published': 'Tue, 01 Dec 2020 08:00:00 GMT', 'published_parsed': time.struct_time(tm_year=2020, tm_mon=12, tm_mday=1, tm_hour=8, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=336, tm_isdst=0), 'summary': '<a href="https://wydaily.com/obits/2020/12/01/alan-denton-averill-worked-in-computer-programming-for-many-years/" target="_blank">Alan Denton Averill, worked in computer programming for many years</a>&nbsp;&nbsp;<font color="#6f6f6f">WYDaily</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https://wydaily.com/obits/2020/12/01/alan-denton-averill-worked-in-computer-programming-for-many-years/" target="_blank">Alan Denton Averill, worked in computer programming for many years</a>&nbsp;&nbsp;<font color="#6f6f6f">WYDaily</font>'}, 'source': {'href': 'https://wydaily.com', 'title': 'WYDaily'}}
# {'title': 'How to become a computer programmer without a degree - IT PRO', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': 'How to become a computer programmer without a degree - IT PRO'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.itpro.co.uk/business-strategy/careers-training/356515/how-to-become-a-computer-programmer-without-a-degree'}], 'link': 'https://www.itpro.co.uk/business-strategy/careers-training/356515/how-to-become-a-computer-programmer-without-a-degree', 'id': '', 'guidislink': False, 'published': 'Mon, 20 Jul 2020 20:16:59 GMT', 'published_parsed': time.struct_time(tm_year=2020, tm_mon=7, tm_mday=20, tm_hour=20, tm_min=16, tm_sec=59, tm_wday=0, tm_yday=202, tm_isdst=0), 'summary': '<a href="https://www.itpro.co.uk/business-strategy/careers-training/356515/how-to-become-a-computer-programmer-without-a-degree" target="_blank">How to become a computer programmer without a degree</a>&nbsp;&nbsp;<font color="#6f6f6f">IT PRO</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https://www.itpro.co.uk/business-strategy/careers-training/356515/how-to-become-a-computer-programmer-without-a-degree" target="_blank">How to become a computer programmer without a degree</a>&nbsp;&nbsp;<font color="#6f6f6f">IT PRO</font>'}, 'source': {'href': 'https://www.itpro.co.uk', 'title': 'IT PRO'}}
# {'title': 'Penn State Wilkes-Barre partners to make programming accessible to youth | Penn State University - Penn State News', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': 'Penn State Wilkes-Barre partners to make programming accessible to youth | Penn State University - Penn State News'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://news.psu.edu/story/642023/2020/12/14/impact/penn-state-wilkes-barre-partners-make-programming-accessible-youth'}], 'link': 'https://news.psu.edu/story/642023/2020/12/14/impact/penn-state-wilkes-barre-partners-make-programming-accessible-youth', 'id': 'CBMidmh0dHBzOi8vbmV3cy5wc3UuZWR1L3N0b3J5LzY0MjAyMy8yMDIwLzEyLzE0L2ltcGFjdC9wZW5uLXN0YXRlLXdpbGtlcy1iYXJyZS1wYXJ0bmVycy1tYWtlLXByb2dyYW1taW5nLWFjY2Vzc2libGUteW91dGjSAQA', 'guidislink': False, 'published': 'Mon, 14 Dec 2020 08:00:00 GMT', 'published_parsed': time.struct_time(tm_year=2020, tm_mon=12, tm_mday=14, tm_hour=8, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=349, tm_isdst=0), 'summary': '<a href="https://news.psu.edu/story/642023/2020/12/14/impact/penn-state-wilkes-barre-partners-make-programming-accessible-youth" target="_blank">Penn State Wilkes-Barre partners to make programming accessible to youth | Penn State University</a>&nbsp;&nbsp;<font color="#6f6f6f">Penn State News</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https://news.psu.edu/story/642023/2020/12/14/impact/penn-state-wilkes-barre-partners-make-programming-accessible-youth" target="_blank">Penn State Wilkes-Barre partners to make programming accessible to youth | Penn State University</a>&nbsp;&nbsp;<font color="#6f6f6f">Penn State News</font>'}, 'source': {'href': 'https://news.psu.edu', 'title': 'Penn State News'}}
# {'title': 'Video Highlights: Pi and The Art of Computer Programming - insideBIGDATA', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': 'Video Highlights: Pi and The Art of Computer Programming - insideBIGDATA'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://insidebigdata.com/2020/05/24/video-highlights-pi-and-the-art-of-computer-programming/'}], 'link': 'https://insidebigdata.com/2020/05/24/video-highlights-pi-and-the-art-of-computer-programming/', 'id': 'CBMiXWh0dHBzOi8vaW5zaWRlYmlnZGF0YS5jb20vMjAyMC8wNS8yNC92aWRlby1oaWdobGlnaHRzLXBpLWFuZC10aGUtYXJ0LW9mLWNvbXB1dGVyLXByb2dyYW1taW5nL9IBAA', 'guidislink': False, 'published': 'Sun, 24 May 2020 07:00:00 GMT', 'published_parsed': time.struct_time(tm_year=2020, tm_mon=5, tm_mday=24, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=145, tm_isdst=0), 'summary': '<a href="https://insidebigdata.com/2020/05/24/video-highlights-pi-and-the-art-of-computer-programming/" target="_blank">Video Highlights: Pi and The Art of Computer Programming</a>&nbsp;&nbsp;<font color="#6f6f6f">insideBIGDATA</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https://insidebigdata.com/2020/05/24/video-highlights-pi-and-the-art-of-computer-programming/" target="_blank">Video Highlights: Pi and The Art of Computer Programming</a>&nbsp;&nbsp;<font color="#6f6f6f">insideBIGDATA</font>'}, 'source': {'href': 'https://insidebigdata.com', 'title': 'insideBIGDATA'}}
# {'title': '7 Famous Computer Programmers Who Started Programming at an Early Age - Interesting Engineering', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '7 Famous Computer Programmers Who Started Programming at an Early Age - Interesting Engineering'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://interestingengineering.com/7-famous-computer-programmers-who-started-programming-at-an-early-age'}], 'link': 'https://interestingengineering.com/7-famous-computer-programmers-who-started-programming-at-an-early-age', 'id': 'CAIiEAQ3vyXXol1rwDNc4BgxQpsqGQgEKhAIACoHCAowy5qUCzDYxqkDMMzwwQY', 'guidislink': False, 'published': 'Tue, 05 May 2020 07:00:00 GMT', 'published_parsed': time.struct_time(tm_year=2020, tm_mon=5, tm_mday=5, tm_hour=7, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=126, tm_isdst=0), 'summary': '<a href="https://interestingengineering.com/7-famous-computer-programmers-who-started-programming-at-an-early-age" target="_blank">7 Famous Computer Programmers Who Started Programming at an Early Age</a>&nbsp;&nbsp;<font color="#6f6f6f">Interesting Engineering</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https
, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.upi.com/Odd_News/2020/11/10/6-year-old-becomes-worlds-youngest-computer-programmer/2191605024211/'}], 'link': 'https://www.upi.com/Odd_News/2020/11/10/6-year-old-becomes-worlds-youngest-computer-programmer/2191605024211/', 'id': 'CAIiEJ4VABU9iy-IS4Vu8HOU67oqFwgEKg8IACoHCAowyrnjAjC42xswkrAl', 'guidislink': False, 'published': 'Tue, 10 Nov 2020 08:00:00 GMT', 'published_parsed': time.struct_time(tm_year=2020, tm_mon=11, tm_mday=10, tm_hour=8, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=315, tm_isdst=0), 'summary': '<a href="https://www.upi.com/Odd_News/2020/11/10/6-year-old-becomes-worlds-youngest-computer-programmer/2191605024211/" target="_blank">6-year-old becomes world\'s youngest computer programmer</a>&nbsp;&nbsp;<font color="#6f6f6f">UPI News</font>', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.google.com/rss/search?q=Computer-Programming&hl=en-US&sort=date&gl=US&num=100&ceid=US:en', 'value': '<a href="https://www.upi.com/Odd_News/2020/11/10/6-year-old-becomes-worlds-youngest-computer-programmer/2191605024211/" target="_blank">6-year-old becomes world\'s youngest computer programmer</a>&nbsp;&nbsp;<font color="#6f6f6f">UPI News</font>'}, 'source': {'href': 'https://www.upi.com', 'title': 'UPI News'}}

# %%
data
# Out:
# [{'Description': "Get 'Computer Programming for Absolute Beginners' ($24.99 value) for FREE  BetaNews",
#   'Published Date': 'Thu, 18 Mar 2021 14:09:16 GMT',
#   'Title': "Get 'Computer Programming for Absolute Beginners' ($24.99 value) for FREE - BetaNews",
#   'Url': 'https://betanews.com/2021/03/18/computer-programming-for-absolute-beginners-free/'},
#  {'Description': "One young artist's search to balance art and computer programming  The Warwick Advertiser",
#   'Published Date': 'Fri, 12 Mar 2021 19:07:30 GMT',
#   'Title': "One young artist's search to balance art and computer programming - The Warwick Advertiser",
#   'Url': 'http://www.warwickadvertiser.com/news/local-news/one-young-artist-s-search-to-balance-art-and-computer-programming-XF1557330'},
#  {'Description': 'Plano students win top honors in all-girls computer programming competition  The Dallas Morning News',
#   'Published Date': 'Mon, 01 Mar 2021 08:00:00 GMT',
#   'Title': 'Plano students win top honors in all-girls computer programming competition - The Dallas Morning News',
#   'Url': 'https://www.dallasnews.com/news/education/2021/03/01/plano-students-win-top-honors-in-all-girls-computer-programming-competition/'},
#  {'Description': 'Now everyone wants to be a software developer, as interest in coding rockets  TechRepublic',
#   'Published Date': 'Wed, 17 Mar 2021 01:01:00 GMT',
#   'Title': 'Now everyone wants to be a software developer, as interest in coding rockets - TechRepublic',
#   'Url': 'https://www.techrepublic.com/article/now-everyone-wants-to-be-a-software-developer-as-interest-in-coding-rockets/'},
#  {'Description': 'These 15 Coding Books Might Spark the Inner Programmer in Your Kid  POPSUGAR',
#   'Published Date': 'Fri, 19 Mar 2021 21:10:03 GMT',
#   'Title': 'These 15 Coding Books Might Spark the Inner Programmer in Your Kid - POPSUGAR',
#   'Url': 'https://www.popsugar.com/family/books-about-coding-for-kids-48216978'},
#  {'Description': 'Syracuse University to offer online, part-time computer programming degree  The Daily Orange',
#   'Published Date': 'Wed, 24 Feb 2021 08:00:00 GMT',
#   'Title': 'Syracuse University to offer online, part-time computer programming degree - The Daily Orange',
#   'Url': 'http://dailyorange.com/2021/02/syracuse-university-offer-online-part-time-computer-programming-degree/'},
#  {'Description': 'Launch a career in computer programming with a boost from this low-cost course bundle  Newsday',
#   'Published Date': 'Tue, 16 Mar 2021 12:00:48 GMT',
#   'Title': 'Launch a career in computer programming with a boost from this low-cost course bundle - Newsday',
#   'Url': 'https://www.newsday.com/lifestyle/fashion-and-shopping/deals/premium-python-certification-bootcamp-bundle-1.50181018'},
#  {'Description': 'How does the brain interpret computer languages?  Ars Technica',
#   'Published Date': 'Mon, 15 Mar 2021 17:58:01 GMT',
#   'Title': 'How does the brain interpret computer languages? - Ars Technica',
#   'Url': 'https://arstechnica.com/science/2021/03/how-does-the-brain-interpret-computer-languages/'},
#  {'Description': 'Coding for Qubits: How to Program in Quantum Computer Assembly Language  IEEE Spectrum',
#   'Published Date': 'Fri, 19 Feb 2021 08:00:00 GMT',
#   'Title': 'Coding for Qubits: How to Program in Quantum Computer Assembly Language - IEEE Spectrum',
#   'Url': 'https://spectrum.ieee.org/tech-talk/computing/software/qscout-sandia-open-source-quantum-computer-and-jaqal-quantum-assembly-language'},
#  {'Description': 'North High students donate laptops to area children  Herald-Mail Media',
#   'Published Date': 'Sat, 20 Mar 2021 19:15:00 GMT',
#   'Title': 'North High students donate laptops to area children - Herald-Mail Media',
#   'Url': 'https://www.heraldmailmedia.com/news/local/north-high-students-donate-laptops-to-area-children/article_821be475-1edf-5bf5-a430-36f971378b2f.html'},
#  {'Description': 'Now Hiring: Software Developer, Computer Programming, Cyber Security Are All In-Demand Gigs  Yahoo News',
#   'Published Date': 'Tue, 02 Mar 2021 08:00:00 GMT',
#   'Title': 'Now Hiring: Software Developer, Computer Programming, Cyber Security Are All In-Demand Gigs - Yahoo News',
#   'Url': 'https://news.yahoo.com/now-hiring-software-developer-computer-225700670.html'},
#  {'Description': "'Shark Tank' appearance gives 500% boost to metro Detroit native's coding app for kids  Detroit Free Press",
#   'Published Date': 'Wed, 17 Mar 2021 16:08:29 GMT',
#   'Title': "'Shark Tank' appearance gives 500% boost to metro Detroit native's coding app for kids - Detroit Free Press",
#   'Url': 'https://www.freep.com/story/news/local/michigan/2021/03/17/shark-tank-mark-cuban-hopscotch-coding-app/4705991001/'},
#  {'Description': 'YouTuber Estefannie Explains It All Shares Computer Programming Tutorials That Anyone Can Follow  Elite Daily',
#   'Published Date': 'Wed, 10 Mar 2021 08:00:00 GMT',
#   'Title': 'YouTuber Estefannie Explains It All Shares Computer Programming Tutorials That Anyone Can Follow - Elite Daily',
#   'Url': 'https://www.elitedaily.com/p/youtuber-estefannie-explains-it-all-shares-computer-programming-tutorials-that-anyone-can-follow-64269572'},
#  {'Description': 'Georgia Tech Python Programming Professional Computing Certificate Launched  Newswire',
#   'Published Date': 'Sat, 20 Mar 2021 01:28:51 GMT',
#   'Title': 'Georgia Tech Python Programming Professional Computing Certificate Launched - Newswire',
#   'Url': 'https://newswire.net/newsroom/pr/00178919-https-tidd-ly-3n-ac-jcu.html'},
#  {'Description': 'Lander College for Men Alum Shares His Tech Career Advice  Touro College News',
#   'Published Date': 'Fri, 19 Mar 2021 00:49:47 GMT',
#   'Title': 'Lander College for Men Alum Shares His Tech Career Advice - Touro College News',
#   'Url': 'https://lcm.touro.edu/news-and-events/news/lander-college-for-men-alum-shares-his-tech-career-advice.php'},
#  {'Description': 'IBM updates quantum programming tools  ZDNet',
#   'Published Date': 'Tue, 16 Mar 2021 15:41:31 GMT',
#   'Title': 'IBM updates quantum programming tools - ZDNet',
#   'Url': 'https://www.zdnet.com/article/ibm-updates-quantum-programming-tools/'},
#  {'Description': 'Best laptop for programming in 2021: top picks for coders, developers and sysadmins – Bestgamingpro  Best gaming pro',
#   'Published Date': 'Sat, 20 Mar 2021 22:30:11 GMT',
#   'Title': 'Best laptop for programming in 2021: top picks for coders, developers and sysadmins – Bestgamingpro - Best gaming pro',
#   'Url': 'https://bestgamingpro.com/best-laptop-for-programming-in-2021-top-picks-for-coders-developers-and-sysadmins/'},
#  {'Description': "'Girls Who Code' makes its debut at the College  The Signal",
#   'Published Date': 'Thu, 18 Mar 2021 02:31:22 GMT',
#   'Title': "'Girls Who Code' makes its debut at the College - The Signal",
#   'Url': 'https://tcnjsignal.net/2021/03/17/girls-who-code-makes-its-debut-at-the-college/'},
#  {'Description': 'More people are taking up software development and coding skills  DevOps Online',
#   'Published Date': 'Fri, 19 Mar 2021 10:01:38 GMT',
#   'Title': 'More people are taking up software development and coding skills - DevOps Online',
#   'Url': 'https://www.devopsonline.co.uk/more-people-are-taking-up-software-development-and-coding-skills/'},
#  {'Description': 'Carlos Córdova Obituary (1945 - 2021) - San Jose, CA - The Blade  Legacy.com',
#   'Published Date': 'Sun, 21 Mar 2021 05:12:21 GMT',
#   'Title': 'Carlos Córdova Obituary (1945 - 2021) - San Jose, CA - The Blade - Legacy.com',
#   'Url': 'https://www.legacy.com/obituaries/toledoblade/obituary.aspx?n=carlos-andres-cordova&pid=198102188'},
#  {'Description': 'Sunset Middle gets computer science boost through Amazon STEM program  Longmont Times-Call',
#   'Published Date': 'Thu, 18 Mar 2021 00:01:42 GMT',
#   'Title': 'Sunset Middle gets computer science boost through Amazon STEM program - Longmont Times-Call',
#   'Url': 'https://www.timescall.com/2021/03/17/sunset-middle-gets-computer-science-boost-through-amazon-stem-program'},
#  {'Description': 'New Arkansas bill proposed to classify computer science as foreign language  KARK',
#   'Published Date': 'Mon, 15 Mar 2021 23:37:53 GMT',
#   'Title': 'New Arkansas bill proposed to classify computer science as foreign language - KARK',
#   'Url': 'https://www.kark.com/news/local-news/new-arkansas-bill-proposed-to-classify-computer-science-as-foreign-language/'},
#  {'Description': 'Coding and software development are top skills chosen to aid employment opportunities  Intelligent CIO ME',
#   'Published Date': 'Wed, 17 Mar 2021 12:19:09 GMT',
#   'Title': 'Coding and software development are top skills chosen to aid employment opportunities - Intelligent CIO ME',
#   'Url': 'https://www.intelligentcio.com/eu/2021/03/17/coding-and-software-development-are-top-skills-chosen-to-aid-employment-opportunities/'},
#  {'Description': "Thomas Joseph 'Tom,' 'Tommy' Gaven Jr., 62, retired computer programmer with the IRS  Port City Daily",
#   'Published Date': 'Wed, 03 Mar 2021 08:00:00 GMT',
#   'Title': "Thomas Joseph 'Tom,' 'Tommy' Gaven Jr., 62, retired computer programmer with the IRS - Port City Daily",
#   'Url': 'https://portcitydaily.com/obits/2021/03/03/thomas-joseph-tom-tommy-gaven-jr-62-retired-computer-programmer-with-the-irs/'},
#  {'Description': 'These Are the Most Popular Programming Languages in 2021  TechDecisions',
#   'Published Date': 'Wed, 17 Mar 2021 20:03:45 GMT',
#   'Title': 'These Are the Most Popular Programming Languages in 2021 - TechDecisions',
#   'Url': 'https://mytechdecisions.com/mobility/these-are-the-most-popular-programming-languages-in-2021/'},
#  {'Description': 'Annual camp expo set for virtual format -  CBS19 News',
#   'Published Date': 'Sat, 13 Mar 2021 02:23:00 GMT',
#   'Title': 'Annual camp expo set for virtual format - - CBS19 News',
#   'Url': 'http://www.cbs19news.com/story/43491002/annual-camp-expo-set-for-virtual-format'},
#  {'Description': 'New bookstore owners plan for post-pandemic future  Vermont Biz',
#   'Published Date': 'Sat, 20 Mar 2021 15:25:52 GMT',
#   'Title': 'New bookstore owners plan for post-pandemic future - Vermont Biz',
#   'Url': 'https://vermontbiz.com/news/2021/march/21/new-bookstore-owners-plan-post-pandemic-future'},
#  {'Description': 'NMSU amplifies success with Google Tech Exchange program  New Mexico State University NewsCenter',
#   'Published Date': 'Thu, 18 Mar 2021 20:58:29 GMT',
#   'Title': 'NMSU amplifies success with Google Tech Exchange program - New Mexico State University NewsCenter',
#   'Url': 'http://newscenter.nmsu.edu/Articles/view/14646/nmsu-amplifies-success-with-google-tech-exchange-program'},
#  {'Description': 'Early theatre students taking One-Act Play to bi-district competition  Brownwood Bulletin',
#   'Published Date': 'Fri, 19 Mar 2021 20:37:48 GMT',
#   'Title': 'Early theatre students taking One-Act Play to bi-district competition - Brownwood Bulletin',
#   'Url': 'https://www.brownwoodtx.com/story/news/2021/03/19/early-theatre-students-taking-one-act-play-bi-district-competition/4771493001/'},
#  {'Description': 'Nevada DETR gives status of unemployment extensions under American Rescue Plan Act of 2021 | Carson City Nevada News  Carson Now',
#   'Published Date': 'Tue, 16 Mar 2021 14:48:45 GMT',
#   'Title': 'Nevada DETR gives status of unemployment extensions under American Rescue Plan Act of 2021 | Carson City Nevada News - Carson Now',
#   'Url': 'https://carsonnow.org/story/03/16/2021/nevada-detr-gives-status-unemployment-extensions-under-american-rescue-plan-act-202?page=805'},
#  {'Description': 'NPCC to offer intro to LEGO Robotics  NTV',
#   'Published Date': 'Fri, 19 Mar 2021 20:18:47 GMT',
#   'Title': 'NPCC to offer intro to LEGO Robotics - NTV',
#   'Url': 'https://nebraska.tv/news/local/npcc-to-offer-intro-to-lego-robotics'},
#  {'Description': 'Children keen to grasp opportunities that help reveal the code to success - Chinadaily.com.cn  China Daily',
#   'Published Date': 'Tue, 16 Mar 2021 16:00:00 GMT',
#   'Title': 'Children keen to grasp opportunities that help reveal the code to success - Chinadaily.com.cn - China Daily',
#   'Url': 'https://www.xeniagazette.com/news/52594/miami-valley-man-is-first-local-space-force-recruit'},
#  {'Description': 'Lopez lives, learns alongside students as faculty-in-residence  Times Record News',
#   'Published Date': 'Thu, 18 Mar 2021 19:52:30 GMT',
#   'Title': 'Lopez lives, learns alongside students as faculty-in-residence - Times Record News',
#   'Url': 'https://www.timesrecordnews.com/story/news/local/2021/03/19/lopez-lives-learns-alongside-students-faculty-residence/4765709001/'},
#  {'Description': 'Three IIMs to offer 5-year undergrad-to-MBA course  Times of India',
#   'Published Date': 'Sun, 21 Mar 2021 01:31:00 GMT',
#   'Title': 'Three IIMs to offer 5-year undergrad-to-MBA course - Times of India',
#   'Url': 'https://timesofindia.indiatimes.com/home/education/three-iims-to-offer-5-year-undergrad-to-mba-course/articleshow/81611834.cms'},
#  {'Description': 'Northwest News | Community News, Photos, Events & Deals on Mobile  KLAS - 8 News Now',
#   'Published Date': 'Tue, 16 Mar 2021 14:15:00 GMT',
#   'Title': 'Northwest News | Community News, Photos, Events & Deals on Mobile - KLAS - 8 News Now',
#   'Url': 'http://northwest.8newsnow.com/news/2863232-detr-unemployment-benefits-extended-until-sept-expect-delay-start'},
#  {'Description': 'IIT Madras and Online Coding Platform Codingal Partner to Enhance Computer Science Learning in Indian Schools  DATAQUEST',
#   'Published Date': 'Wed, 17 Mar 2021 15:14:54 GMT',
#   'Title': 'IIT Madras and Online Coding Platform Codingal Partner to Enhance Computer Science Learning in Indian Schools - DATAQUEST',
#   'Url': 'https://www.dqindia.com/iit-madras-online-coding-platform-codingal-partner-enhance-computer-science-learning-indian-schools/'},
#  {'Description': 'Quantum computing software takes center stage  ITProPortal',
#   'Published Date': 'Fri, 19 Mar 2021 09:00:19 GMT',
#   'Title': 'Quantum computing software takes center stage - ITProPortal',
#   'Url': 'https://www.itproportal.com/features/quantum-computing-software-takes-center-stage/'},
#  {'Description': 'Will AI Write the Next Great American Novel?  CALIFORNIA',
#   'Published Date': 'Mon, 15 Mar 2021 19:23:37 GMT',
#   'Title': 'Will AI Write the Next Great American Novel? - CALIFORNIA',
#   'Url': 'https://alumni.berkeley.edu/california-magazine/spring-2021/will-ai-write-the-next-great-american-novel'},
#  {'Description': 'Robots Transform Student Lives  Energy.gov',
#   'Published Date': 'Fri, 05 Mar 2021 08:00:00 GMT',
#   'Title': 'Robots Transform Student Lives - Energy.gov',
#   'Url': 'https://www.energy.gov/articles/robots-transform-student-lives'},
#  {'Description': 'Video gaming association commits $1 million to support Black Girls Code  KNBR',
#   'Published Date': 'Sun, 14 Mar 2021 08:58:47 GMT',
#   'Title': 'Video gaming association commits $1 million to support Black Girls Code - KNBR',
#   'Url': 'https://www.knbr.com/news/video-gaming-association-commits-1-million-to-support-black-girls-code/'},
#  {'Description': 'Airspace Granted Patent for Its Industry-Changing Logistics Management System  Business Wire',
#   'Published Date': 'Wed, 17 Mar 2021 13:00:00 GMT',
#   'Title': 'Airspace Granted Patent for Its Industry-Changing Logistics Management System - Business Wire',
#   'Url': 'https://www.businesswire.com/news/home/20210317005325/en/Airspace-Granted-Patent-for-Its-Industry-Changing-Logistics-Management-System'},
#  {'Description': 'Textnets: Software to make large amounts of text visually comprehensible  Tech Xplore',
#   'Published Date': 'Thu, 18 Mar 2021 13:46:41 GMT',
#   'Title': 'Textnets: Software to make large amounts of text visually comprehensible - Tech Xplore',
#   'Url': 'https://techxplore.com/news/2021-03-textnets-software-large-amounts-text.html'},
#  {'Description': 'Best coding course deal: Java, C#, Python, Redux, and more (UK deal)  Mashable',
#   'Published Date': 'Fri, 19 Mar 2021 05:00:00 GMT',
#   'Title': 'Best coding course deal: Java, C#, Python, Redux, and more (UK deal) - Mashable',
#   'Url': 'https://mashable.com/uk/shopping/march-19-software-developer-certification-bundle-sale/'},
#  {'Description': 'VIRL organizes coding contest for girls and young women – Vancouver Island Free Daily  vancouverislandfreedaily.com',
#   'Published Date': 'Tue, 16 Mar 2021 13:55:00 GMT',
#   'Title': 'VIRL organizes coding contest for girls and young women – Vancouver Island Free Daily - vancouverislandfreedaily.com',
#   'Url': 'https://www.vancouverislandfreedaily.com/community/virl-organizes-coding-contest-for-girls-and-young-women/'},
#  {'Description': 'SmartNICs Will Radically Change the Data Center  StorageReview.com',
#   'Published Date': 'Fri, 19 Mar 2021 15:14:10 GMT',
#   'Title': 'SmartNICs Will Radically Change the Data Center - StorageReview.com',
#   'Url': 'https://www.storagereview.com/news/smartnics-will-radically-change-the-data-center'},
#  {'Description': 'Your Illinois News Radar » Harmon talks remap, looks to Oklahoma for possible deadline solution  The Capitol Fax Blog',
#   'Published Date': 'Wed, 17 Mar 2021 20:09:08 GMT',
#   'Title': 'Your Illinois News Radar » Harmon talks remap, looks to Oklahoma for possible deadline solution - The Capitol Fax Blog',
#   'Url': 'https://capitolfax.com/2021/03/17/harmon-talks-remap-looks-to-oklahoma-for-possible-deadline-solution/'},
#  {'Description': "Tekie – India's First Animated Coding Startup, Emerges as a Major Contender to WhiteHat Jr  APN News",
#   'Published Date': 'Thu, 18 Mar 2021 17:55:01 GMT',
#   'Title': "Tekie – India's First Animated Coding Startup, Emerges as a Major Contender to WhiteHat Jr - APN News",
#   'Url': 'https://www.apnnews.com/tekie-indias-first-animated-coding-startup-emerges-as-a-major-contender-to-whitehat-jr/'},
#  {'Description': 'From Tipperary to Silicon Valley: how Stripe became vital cog in digital economy  The Guardian',
#   'Published Date': 'Wed, 17 Mar 2021 06:00:00 GMT',
#   'Title': 'From Tipperary to Silicon Valley: how Stripe became vital cog in digital economy - The Guardian',
#   'Url': 'https://www.theguardian.com/business/2021/mar/17/from-tipperary-to-silicon-valley-how-stripe-became-vital-cog-in-digital-economy'},
#  {'Description': 'The community college question  Montana Free Press',
#   'Published Date': 'Fri, 19 Mar 2021 23:18:56 GMT',
#   'Title': 'The community college question - Montana Free Press',
#   'Url': 'https://montanafreepress.org/2021/03/19/the-community-college-question/'},
#  {'Description': 'How the brain is programmed for computer programming?  Medical Xpress',
#   'Published Date': 'Thu, 28 Jan 2021 08:00:00 GMT',
#   'Title': 'How the brain is programmed for computer programming? - Medical Xpress',
#   'Url': 'https://medicalxpress.com/news/2021-01-brain-2.html'},
#  {'Description': "Master's in Business Analytics: Jolee Zhao, USC Marshall School of Business  Poets&Quants",
#   'Published Date': 'Tue, 16 Mar 2021 22:11:22 GMT',
#   'Title': "Master's in Business Analytics: Jolee Zhao, USC Marshall School of Business - Poets&Quants",
#   'Url': 'https://poetsandquants.com/2021/03/16/masters-in-business-analytics-jolee-zhao-usc-marshall-school-of-business/?pq-category=students'},
#  {'Description': 'Piper Make: First Drag-and-Drop Coding Platform for Raspberry Pi Pico  CNX Software',
#   'Published Date': 'Sun, 14 Mar 2021 18:01:34 GMT',
#   'Title': 'Piper Make: First Drag-and-Drop Coding Platform for Raspberry Pi Pico - CNX Software',
#   'Url': 'https://www.cnx-software.com/2021/03/15/piper-make-first-drag-and-drop-coding-platform-for-raspberry-pi-pico/'},
#  {'Description': 'RRB NTPC 2021 Exam Memory Based Computer Questions: Check General Awareness (GA)/GK/Current Affairs Questions with Answers  Jagran Josh',
#   'Published Date': 'Fri, 19 Mar 2021 06:53:15 GMT',
#   'Title': 'RRB NTPC 2021 Exam Memory Based Computer Questions: Check General Awareness (GA)/GK/Current Affairs Questions with Answers - Jagran Josh',
#   'Url': 'https://www.jagranjosh.com/articles/rrb-ntpc-2021-exam-memory-based-computer-questions-with-answers-general-awareness-ga-gk-current-affairs-1616136747-1'},
#  {'Description': 'Numeracy Challenge held at Four County  Fcnews.org',
#   'Published Date': 'Tue, 16 Mar 2021 11:56:30 GMT',
#   'Title': 'Numeracy Challenge held at Four County - Fcnews.org',
#   'Url': 'https://www.fcnews.org/news/29648/numeracy-challenge-held-at-four-county'},
#  {'Description': "Stanford vs UCLA Live Semifinal How To Watch NCAA Men's Water Polo Semifinal Online Free Tv Channel guide  Programming Insider",
#   'Published Date': 'Sat, 20 Mar 2021 18:10:50 GMT',
#   'Title': "Stanford vs UCLA Live Semifinal How To Watch NCAA Men's Water Polo Semifinal Online Free Tv Channel guide - Programming Insider",
#   'Url': 'https://programminginsider.com/stanford-vs-ucla-live-semifinal-how-to-watch-ncaa-mens-water-polo-semifinal-online-free-tv-channel-guide/'},
#  {'Description': 'Learning to code among the top new skills taken up during lockdown, study says  Evening Standard',
#   'Published Date': 'Wed, 17 Mar 2021 00:01:00 GMT',
#   'Title': 'Learning to code among the top new skills taken up during lockdown, study says - Evening Standard',
#   'Url': 'https://www.standard.co.uk/news/uk/red-hat-europe-animation-yougov-b924544.html'},
#  {'Description': 'Meet The Masters Of Business Analytics  Poets&Quants',
#   'Published Date': 'Wed, 17 Mar 2021 14:35:13 GMT',
#   'Title': 'Meet The Masters Of Business Analytics - Poets&Quants',
#   'Url': 'https://poetsandquants.com/2021/03/17/meet-the-masters-of-business-analytics/'},
#  {'Description': 'This is your brain on code: JHU researchers decipher neural mechanics of computer programming  The Hub at Johns Hopkins',
#   'Published Date': 'Thu, 17 Dec 2020 08:00:00 GMT',
#   'Title': 'This is your brain on code: JHU researchers decipher neural mechanics of computer programming - The Hub at Johns Hopkins',
#   'Url': 'https://hub.jhu.edu/2020/12/17/brain-activity-while-reading-code/'},
#  {'Description': "A 6 year old became the world's youngest computer programmer  TechRepublic",
#   'Published Date': 'Thu, 28 Jan 2021 08:00:00 GMT',
#   'Title': "A 6 year old became the world's youngest computer programmer - TechRepublic",
#   'Url': 'https://www.techrepublic.com/article/a-6-year-old-became-the-worlds-youngest-computer-programmer/'},
#  {'Description': 'Vanderbilt Digital Nights computer programming workshop series for high school students begins Nov. 19  Vanderbilt University News',
#   'Published Date': 'Fri, 13 Nov 2020 08:00:00 GMT',
#   'Title': 'Vanderbilt Digital Nights computer programming workshop series for high school students begins Nov. 19 - Vanderbilt University News',
#   'Url': 'https://news.vanderbilt.edu/2020/11/13/vanderbilt-digital-nights-computer-programming-workshop-series-for-high-school-students-begins-nov-19/'},
#  {'Description': 'Local invention transforms students into computer programmers  WHNT News 19',
#   'Published Date': 'Mon, 01 Feb 2021 08:00:00 GMT',
#   'Title': 'Local invention transforms students into computer programmers - WHNT News 19',
#   'Url': 'https://whnt.com/news/madison/local-invention-transforms-students-into-computer-programmers/'},
#  {'Description': 'To the brain, reading computer code is not the same as reading language  MIT News',
#   'Published Date': 'Tue, 15 Dec 2020 08:00:00 GMT',
#   'Title': 'To the brain, reading computer code is not the same as reading language - MIT News',
#   'Url': 'https://news.mit.edu/2020/brain-reading-computer-code-1215'},
#  {'Description': 'What is Computer Programming | Become a Computer Programmer  Southern New Hampshire University',
#   'Published Date': 'Fri, 14 Dec 2018 23:48:56 GMT',
#   'Title': 'What is Computer Programming | Become a Computer Programmer - Southern New Hampshire University',
#   'Url': 'https://www.snhu.edu/about-us/newsroom/2018/06/what-is-computer-programming'},
#  {'Description': 'Round Rock Kids Invited To Learn Computer Programming  Patch.com',
#   'Published Date': 'Thu, 11 Feb 2021 08:00:00 GMT',
#   'Title': 'Round Rock Kids Invited To Learn Computer Programming - Patch.com',
#   'Url': 'https://patch.com/texas/round-rock/round-rock-kids-invited-learn-computer-programming'},
#  {'Description': 'Neil Gorchow, Sperry executive who took part in early computer programming, dies at 95  The Philadelphia Inquirer',
#   'Published Date': 'Wed, 30 Dec 2020 08:00:00 GMT',
#   'Title': 'Neil Gorchow, Sperry executive who took part in early computer programming, dies at 95 - The Philadelphia Inquirer',
#   'Url': 'https://www.inquirer.com/obituaries/neil-gorchow-sperry-univac-computer-programming-executive-space-missions-dies-died-obituary-obituaries-20201230.html'},
#  {'Description': 'JHU scientists decode neural mechanisms of computer programming  News-Medical.net',
#   'Published Date': 'Tue, 15 Dec 2020 08:00:00 GMT',
#   'Title': 'JHU scientists decode neural mechanisms of computer programming - News-Medical.net',
#   'Url': 'https://www.news-medical.net/news/20201215/JHU-scientists-decode-neural-mechanisms-of-computer-programming.aspx'},
#  {'Description': 'Middle-Schoolers to Learn Computer-Coding Skills through UMass Lowell-Led Program  UMass Lowell',
#   'Published Date': 'Thu, 10 Sep 2020 07:00:00 GMT',
#   'Title': 'Middle-Schoolers to Learn Computer-Coding Skills through UMass Lowell-Led Program - UMass Lowell',
#   'Url': 'https://www.uml.edu/news/press-releases/2020/martincspathways091020.aspx'},
#  {'Description': 'University of Montevallo offers robust computer program curriculum  University of Montevallo News',
#   'Published Date': 'Thu, 07 May 2020 07:00:00 GMT',
#   'Title': 'University of Montevallo offers robust computer program curriculum - University of Montevallo News',
#   'Url': 'https://www.montevallo.edu/university-of-montevallo-offers-robust-computer-program-curriculum/'},
#  {'Description': 'Class gives students look at the computer programming industry  Columbia Basin Herald',
#   'Published Date': 'Wed, 13 Jan 2021 08:00:00 GMT',
#   'Title': 'Class gives students look at the computer programming industry - Columbia Basin Herald',
#   'Url': 'https://columbiabasinherald.com/news/2021/jan/13/class-gives-students-look-computer-programming-ind/'},
#  {'Description': '8 of the most popular programming languages  TechRepublic',
#   'Published Date': 'Mon, 04 Jan 2021 08:00:00 GMT',
#   'Title': '8 of the most popular programming languages - TechRepublic',
#   'Url': 'https://www.techrepublic.com/article/8-of-the-most-popular-programming-languages/'},
#  {'Description': 'The essential 10 programming languages developers need to know this year  TechRepublic',
#   'Published Date': 'Thu, 18 Feb 2021 08:00:00 GMT',
#   'Title': 'The essential 10 programming languages developers need to know this year - TechRepublic',
#   'Url': 'https://www.techrepublic.com/article/the-essential-10-programming-languages-developers-need-to-know-this-year/'},
#  {'Description': "Computer programmers can be granted H-1B visas now; US court confirms 'speciality' status  Business Today",
#   'Published Date': 'Mon, 21 Dec 2020 08:00:00 GMT',
#   'Title': "Computer programmers can be granted H-1B visas now; US court confirms 'speciality' status - Business Today",
#   'Url': 'https://www.businesstoday.in/current/world/computer--programmers-can-be-granted-h1b-visas-now-us-court-confirms-specialty-status/story/425481.html'},
#  {'Description': 'Wayne State University, partners invite K-12 and community to break world record in computer science programming with Michigan Accelerate Computer Science virtual event  The South End',
#   'Published Date': 'Mon, 16 Nov 2020 08:00:00 GMT',
#   'Title': 'Wayne State University, partners invite K-12 and community to break world record in computer science programming with Michigan Accelerate Computer Science virtual event - The South End',
#   'Url': 'https://today.wayne.edu/news/2020/11/16/wayne-state-university-partners-invite-k-12-and-community-to-break-world-record-in-computer-science-programming-with-michigan-accelerate-computer-science-virtual-event-40944'},
#  {'Description': 'Ten computer codes that transformed science News Feature  Nature.com',
#   'Published Date': 'Wed, 20 Jan 2021 08:00:00 GMT',
#   'Title': 'Ten computer codes that transformed science News Feature - Nature.com',
#   'Url': 'https://www.nature.com/articles/d41586-021-00075-2'},
#  {'Description': 'From prison to programming: How coding can help inmates find a path out of crime  TechRepublic',
#   'Published Date': 'Tue, 06 Oct 2020 07:00:00 GMT',
#   'Title': 'From prison to programming: How coding can help inmates find a path out of crime - TechRepublic',
#   'Url': 'https://www.techrepublic.com/article/from-prison-to-programming-how-coding-can-help-inmates-find-a-path-out-of-crime/'},
#  {'Description': 'Oak Lawn grad lauded for computer coding skills: ‘I’m interested in knowing the language of the future’  Chicago Tribune',
#   'Published Date': 'Sat, 24 Oct 2020 07:00:00 GMT',
#   'Title': 'Oak Lawn grad lauded for computer coding skills: ‘I’m interested in knowing the language of the future’ - Chicago Tribune',
#   'Url': 'https://www.chicagotribune.com/suburbs/daily-southtown/ct-sta-oak-lawn-computing-award-st-1023-20201024-ee26mll3anedrfd4ujxmva7h74-story.html'},
#  {'Description': 'Alan Denton Averill, worked in computer programming for many years  WYDaily',
#   'Published Date': 'Tue, 01 Dec 2020 08:00:00 GMT',
#   'Title': 'Alan Denton Averill, worked in computer programming for many years - WYDaily',
#   'Url': 'https://wydaily.com/obits/2020/12/01/alan-denton-averill-worked-in-computer-programming-for-many-years/'},
#  {'Description': 'How to become a computer programmer without a degree  IT PRO',
#   'Published Date': 'Mon, 20 Jul 2020 20:16:59 GMT',
#   'Title': 'How to become a computer programmer without a degree - IT PRO',
#   'Url': 'https://www.itpro.co.uk/business-strategy/careers-training/356515/how-to-become-a-computer-programmer-without-a-degree'},
#  {'Description': 'Penn State Wilkes-Barre partners to make programming accessible to youth | Penn State University  Penn State News',
#   'Published Date': 'Mon, 14 Dec 2020 08:00:00 GMT',
#   'Title': 'Penn State Wilkes-Barre partners to make programming accessible to youth | Penn State University - Penn State News',
#   'Url': 'https://news.psu.edu/story/642023/2020/12/14/impact/penn-state-wilkes-barre-partners-make-programming-accessible-youth'},
#  {'Description': 'Video Highlights: Pi and The Art of Computer Programming  insideBIGDATA',
#   'Published Date': 'Sun, 24 May 2020 07:00:00 GMT',
#   'Title': 'Video Highlights: Pi and The Art of Computer Programming - insideBIGDATA',
#   'Url': 'https://insidebigdata.com/2020/05/24/video-highlights-pi-and-the-art-of-computer-programming/'},
#  {'Description': '7 Famous Computer Programmers Who Started Programming at an Early Age  Interesting Engineering',
#   'Published Date': 'Tue, 05 May 2020 07:00:00 GMT',
#   'Title': '7 Famous Computer Programmers Who Started Programming at an Early Age - Interesting Engineering',
#   'Url': 'https://interestingengineering.com/7-famous-computer-programmers-who-started-programming-at-an-early-age'},
#  {'Description': '6-year-old Ahmedabad boy sets world record for being youngest computer programmer  The Indian Express',
#   'Published Date': 'Wed, 11 Nov 2020 08:00:00 GMT',
#   'Title': '6-year-old Ahmedabad boy sets world record for being youngest computer programmer - The Indian Express',
#   'Url': 'https://indianexpress.com/article/trending/trending-in-india/guinness-world-record-words-youngest-computer-programmer-ahmedabad-7046285/'},
#  {'Description': 'How to Learn to Code: A US News Guide - U.S. News & World Report  U.S. News & World Report',
#   'Published Date': 'Wed, 09 Dec 2020 08:00:00 GMT',
#   'Title': 'How to Learn to Code: A US News Guide - U.S. News & World Report - U.S. News & World Report',
#   'Url': 'https://www.usnews.com/education/learn-coding-guide'},
#  {'Description': "6-year-old becomes world's youngest computer programmer  UPI News",
#   'Published Date': 'Tue, 10 Nov 2020 08:00:00 GMT',
#   'Title': "6-year-old becomes world's youngest computer programmer - UPI News",
#   'Url': 'https://www.upi.com/Odd_News/2020/11/10/6-year-old-becomes-worlds-youngest-computer-programmer/2191605024211/'}]
